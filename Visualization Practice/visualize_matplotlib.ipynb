# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sungreong/TIL/blob/master/visualize_matplotlib.ipynb)

# %%
import matplotlib.pyplot as plt

x = range(100)
y= [value **2 for value in x ]
plt.plot(x, y)
plt.show()

# %%
import numpy as np
# pyplot 안에 figure라는 모판이 있음 
## plt.show() #그려진 만큼 찍어주기 
x_1 = range(100)
y_1= [np.cos(value) for value in x_1]

x_2 = range(100)
y_2 = [np.sin(value) for value in x_2]

plt.plot(x_1, y_1)
plt.plot(y_2, x_2)
plt.plot(range(100), range(100))
plt.show()

# %%
## figure 안에 또다른 그림판 만들어 줄 수 있다 .
fig = plt.figure()
fig.set_size_inches(10, 10)
ax_1 = fig.add_subplot(2,2,1)
ax_2 = fig.add_subplot(2,2,4)
ax_1.plot(x_1, y_1 , c="b")
ax_2.plot(x_2, y_2, c="r")
plt.show()

# %%
#Set color
# http://matplotlib.org/2.0.2/api/colors_api.html
x_1 = range(100)
y_1 = [value for value in x_1]

x_2 = range(100)
y_2 = [ a + 100 for a  in x_1]
plt.plot(x_1, y_1 , color="#000000")
plt.plot(x_2, y_2 , c="c")
plt.show()

# %%
# Set linestyle
# https://matplotlib.org/examples/lines_bars_and_markers/linestyles.html

plt.plot(x_1, y_1, c="b", linestyle = "dashed")
plt.plot(x_1, y_2, c="r", linestyle = "dotted")
plt.title("two lines")
plt.show()

# %%
plt.plot(x_1, y_1, c="b", linestyle = "dashed")
plt.plot(x_1, y_2, c="r", linestyle = "dotted")

plt.title(" $y = \\frac{ax+b}{test}$")
plt.show()

# %%
plt.plot(x_1, y_1, c="b", linestyle = "dashed")
plt.plot(x_1, y_2, c="r", linestyle = "dotted")

plt.title("$y = ax+b$")
plt.xlabel("$x_line$")
plt.ylabel("$y_line$")
plt.show()

# %%
plt.plot(x_1, y_1, c="b", linestyle = "dashed")
plt.plot(x_1, y_2, c="r", linestyle = "dotted")

plt.text(50 ,70 , "Line_1")
plt.annotate(
    "line_2" , xy=(50, 150), xytext =(20,175) , 
    arrowprops = dict(facecolor ="b", shrink = 0.05 )
)

plt.title("$y=ax+b$")
plt.xlabel("x_line")
plt.ylabel("y_line")
plt.show()

# %%
plt.plot(x_1, y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(x_2, y_2, color="r", linestyle="dotted", label='line_2')
plt.legend(shadow=True , fancybox=False , loc="upper right")


plt.title('$y = ax+b$')
plt.xlabel('$x_line$')
plt.ylabel('y_line')


plt.show()

# %%
plt.plot(x_1, y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(x_2, y_2, color="r", linestyle="dotted", label='line_2')
plt.legend(shadow=True, fancybox=True, loc="lower right")

plt.grid(True , lw=0.4 , ls="--", c=".90")
plt.xlim(-1000, 1000)
plt.ylim(-1000,2000)
plt.show()

# %%
## scatter 
data_1 = np.random.rand(512, 2)
data_2 = np.random.rand(512, 2)

plt.scatter(data_1[:,0] , data_1[:, 1] , c="b" , marker="x")
plt.scatter(data_2[:,0] , data_2[:, 1], c="r", marker="o")
plt.show()

# %%
n = 50
x= np.random.rand(n)
y= np.random.rand(n)

colors = np.random.rand(n)
area = np.pi* (15* np.random.rand(n))**2
plt.scatter(x, y, s=area , c=colors , alpha=0.5)
plt.show()

# %%
data = [[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]]

X = np.arange(0,8,2)

# %%
plt.bar(X + 0.00, data[0], color = 'b', width = 0.50)
plt.bar(X + 0.50, data[1], color = 'g', width = 0.50)
plt.bar(X + 1.0, data[2], color = 'r', width = 0.50)
plt.xticks(X+0.50, ("A","B","C", "D"))
plt.show()

# %%
data = np.array([[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]])

color_list = ['b', 'g', 'r']
data_label = ["A","B","C"]
X = np.arange(data.shape[1])
print(X)
print(data[1])
print(data[:1])

data = np.array([[5., 5., 5., 5.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]])

for i in range(3):
    plt.bar(X, data[i], bottom = np.sum(data[:i], axis=0), 
            color = color_list[i], label=data_label[i])
plt.legend()
plt.show()
# Out:
# [0 1 2 3]
# [ 4. 23. 51. 17.]
# [[ 5. 25. 50. 20.]]

# %%
A = [5., 30., 45., 22.]
B = [5, 25, 50, 20]

X = range(4)

plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'r', bottom = 60)
plt.show()

# %%
women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([5, 25, 50, 20])
X = np.arange(4)

plt.barh(X, women_pop, color = 'r')
plt.barh(X, -men_pop, color = 'b')
plt.show()

# %%
data = np.random.randn(100,5)
plt.boxplot(data)
plt.show()
