# %% [markdown]
# ## local 에 있는 파일 가져오기!!
#
# 속도는 느리다

# %%
# %%time

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-b7e97590-57a0-41d6-a26a-f9cee72bc643" name="files[]" multiple disabled />
#      <output id="result-b7e97590-57a0-41d6-a26a-f9cee72bc643">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving creditcard.csv to creditcard (1).csv
# User uploaded file "creditcard.csv" with length 150828752 bytes
# CPU times: user 51.2 s, sys: 3.74 s, total: 55 s
# Wall time: 20min 43s

# %%
# !ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Sep 17 10:07 .
# drwxr-xr-x 1 root root 4096 Sep 17 08:44 ..
# drwxr-xr-x 4 root root 4096 Sep 13 17:08 .config
# -rw-r--r-- 1 root root   12 Sep 17 10:07 example.txt
# drwxr-xr-x 2 root root 4096 Sep 13 17:28 sample_data

# %% [markdown]
# ##  여기있는 파일  local에 저장하기

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('local에 저장 할 수 있다. 굳굳')

files.download('example.txt')

# %% [markdown]
# ##  Mounting Google Drive locally
#
# 예전에 비해 훨씬 간단하게 google  Drive 연동되는 코드가 간단해졌다!! (굳굳)
#
#
#
# ```
# from google.colab import drive!
# ```

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd  ./gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive

# %%
ls -al
# Out:
# total 123
# drwx------ 2 root root  4096 Sep 16 05:06 시계열/
# drwx------ 2 root root  4096 May  1 02:49 데이터사이언스/
# drwx------ 2 root root  4096 Mar  3  2018 cs20/
# drwx------ 2 root root  4096 May  1 02:48 Filter Visualization/
# drwx------ 2 root root  4096 Mar  6  2018 GAN/
# -rw------- 1 root root  5022 Mar  5  2018 GPU가능.ipynb
# -rw------- 1 root root 25135 Mar  1  2018 HOW TO IMPORT .PY
# -rw------- 1 root root  7239 Apr 15 06:35 선형대수학코딩.ipynb
# drwx------ 2 root root  4096 May  9 11:30 NLP/
# drwx------ 2 root root  4096 Apr 26 03:19 numpy 연습/
# drwx------ 2 root root  4096 Sep 13 00:29 Pandas/
# drwx------ 2 root root  4096 May  3 00:32 pymc3/
# drwx------ 2 root root  4096 Apr 26 03:18 머신러닝을 위한 python/
# drwx------ 2 root root  4096 Mar 14  2018 Pytorch/
# drwx------ 2 root root  4096 Sep 16 05:03 RL/
# -rw------- 1 root root 10682 Sep 14 01:03 style_transfer.ipynb
# drwx------ 2 root root  4096 Sep 16 11:04 tensorflow/
# drwx------ 2 root root  4096 May  9 11:30 TIL/
# -rw------- 1 root root   229 Sep 17 09:20 Untitled
# -rw------- 1 root root 14570 Sep 18 00:30 Untitled0.ipynb
# drwx------ 2 root root  4096 Sep 13 00:30 visualization Practice/

# %% [markdown]
# ## PyDrive
#
#  1) authentication, 2) file upload, and 3) file download
#
#  pyDrive 를 활용해서 파일 업로드도 가능하고 다운로드도 가능하다

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# Uploaded file with ID 1Aui8k9q7B3cqJMLBtZGN7TnQKpG_pH4E
# Downloaded content "Sample upload file content"

# %%
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)


drive

# %%
# PyDrive reference:
# https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html

# 2. Create & upload a file text file.
uploaded = drive.CreateFile({'title': 'Sample upload.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 10RosHKMFYUHG4mpuezFXRjbqp1ZOVD1Q

# %%
# 3. Load a file by ID and print its contents.
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))

# %% [markdown]
# ## Drive REST API
