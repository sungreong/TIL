# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import functools
import os
import shutil

import adanet
import tensorflow as tf

# The random seed to use.
RANDOM_SEED = 42

LOG_DIR = '/tmp/models'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1228 23:13:02.485604 140099870877440 module_wrapper.py:139] From /root/anaconda3/lib/python3.6/site-packages/adanet/tf_compat/__init__.py:87: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# W1228 23:13:02.500846 140099870877440 module_wrapper.py:139] From /root/anaconda3/lib/python3.6/site-packages/adanet/core/tpu_estimator.py:39: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.

# %% [markdown]
# ## [Medium 글](https://towardsdatascience.com/googles-adanet-uses-neural-networks-to-build-better-neural-networks-36c07eefd4d3)
#
# ## [Github TUTORIAL](https://github.com/tensorflow/adanet/blob/master/adanet/examples/tutorials/adanet_objective.ipynb)

# %%
tf.__version__
# Out:
# '1.15.0'

# %%
#@test {"skip": true}

get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# Install ngrok binary.
# ! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# ! unzip ngrok-stable-linux-amd64.zip

# Delete old logs dir.
shutil.rmtree(LOG_DIR, ignore_errors=True)

# print("Follow this link to open TensorBoard in a new tab.")
# get_ipython().system_raw('./ngrok http 6006 &')
# ! curl -s http://localhost:4040/api/tunnels | python3 -c \
#     "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
(x_train, y_train), (x_test, y_test) = (
    tf.keras.datasets.boston_housing.load_data())

# Preview the first example from the training data
print('Model inputs: %s \n' % x_train[0])
print('Model output (house price): $%s ' % (y_train[0] * 1000))
# Out:
# Model inputs: [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
#
# Model output (house price): $15200.0

# %%
x_train.shape , x_test.shape
# Out:
# ((404, 13), (102, 13))

# %%
x_train
# Out:
# array([[1.23247e+00, 0.00000e+00, 8.14000e+00, ..., 2.10000e+01,
#         3.96900e+02, 1.87200e+01],
#        [2.17700e-02, 8.25000e+01, 2.03000e+00, ..., 1.47000e+01,
#         3.95380e+02, 3.11000e+00],
#        [4.89822e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.75520e+02, 3.26000e+00],
#        ...,
#        [3.46600e-02, 3.50000e+01, 6.06000e+00, ..., 1.69000e+01,
#         3.62250e+02, 7.83000e+00],
#        [2.14918e+00, 0.00000e+00, 1.95800e+01, ..., 1.47000e+01,
#         2.61950e+02, 1.57900e+01],
#        [1.43900e-02, 6.00000e+01, 2.93000e+00, ..., 1.56000e+01,
#         3.76700e+02, 4.38000e+00]])

# %%
FEATURES_KEY = "x"


def input_fn(partition, training, batch_size):
  """Generate an input function for the Estimator."""

  def _input_fn():

    if partition == "train":
      dataset = tf.data.Dataset.from_tensor_slices(({
          FEATURES_KEY: tf.log1p(x_train)
      }, tf.log1p(y_train)))
    else:
      dataset = tf.data.Dataset.from_tensor_slices(({
          FEATURES_KEY: tf.log1p(x_test)
      }, tf.log1p(y_test)))

    # We call repeat after shuffling, rather than before, to prevent separate
    # epochs from blending together.
    if training:
      dataset = dataset.shuffle(10 * batch_size, seed=RANDOM_SEED).repeat()

    dataset = dataset.batch(batch_size)
    iterator = dataset.make_one_shot_iterator()
    features, labels = iterator.get_next()
    return features, labels

  return _input_fn

# %%
_NUM_LAYERS_KEY = "num_layers"


class _SimpleDNNBuilder(adanet.subnetwork.Builder):
  """Builds a DNN subnetwork for AdaNet."""

  def __init__(self, optimizer, layer_size, num_layers, learn_mixture_weights,
               seed):
    """Initializes a `_DNNBuilder`.

    Args:
      optimizer: An `Optimizer` instance for training both the subnetwork and
        the mixture weights.
      layer_size: The number of nodes to output at each hidden layer.
      num_layers: The number of hidden layers.
      learn_mixture_weights: Whether to solve a learning problem to find the
        best mixture weights, or use their default value according to the
        mixture weight type. When `False`, the subnetworks will return a no_op
        for the mixture weight train op.
      seed: A random seed.

    Returns:
      An instance of `_SimpleDNNBuilder`.
    """

    self._optimizer = optimizer
    self._layer_size = layer_size
    self._num_layers = num_layers
    self._learn_mixture_weights = learn_mixture_weights
    self._seed = seed

  def build_subnetwork(self,
                       features,
                       logits_dimension,
                       training,
                       iteration_step,
                       summary,
                       previous_ensemble=None):
    """See `adanet.subnetwork.Builder`."""

    input_layer = tf.to_float(features[FEATURES_KEY])
    kernel_initializer = tf.glorot_uniform_initializer(seed=self._seed)
    last_layer = input_layer
    for _ in range(self._num_layers):
      last_layer = tf.layers.dense(
          last_layer,
          units=self._layer_size,
          activation=tf.nn.relu,
          kernel_initializer=kernel_initializer)
    logits = tf.layers.dense(
        last_layer,
        units=logits_dimension,
        kernel_initializer=kernel_initializer)

    persisted_tensors = {_NUM_LAYERS_KEY: tf.constant(self._num_layers)}
    return adanet.Subnetwork(
        last_layer=last_layer,
        logits=logits,
        complexity=self._measure_complexity(),
        persisted_tensors=persisted_tensors)

  def _measure_complexity(self):
    """Approximates Rademacher complexity as the square-root of the depth."""
    return tf.sqrt(tf.to_float(self._num_layers))

  def build_subnetwork_train_op(self, subnetwork, loss, var_list, labels,
                                iteration_step, summary, previous_ensemble):
    """See `adanet.subnetwork.Builder`."""
    return self._optimizer.minimize(loss=loss, var_list=var_list)

  def build_mixture_weights_train_op(self, loss, var_list, logits, labels,
                                     iteration_step, summary):
    """See `adanet.subnetwork.Builder`."""

    if not self._learn_mixture_weights:
      return tf.no_op()
    return self._optimizer.minimize(loss=loss, var_list=var_list)

  @property
  def name(self):
    """See `adanet.subnetwork.Builder`."""

    if self._num_layers == 0:
      # A DNN with no hidden layers is a linear model.
      return "linear"
    return "{}_layer_dnn".format(self._num_layers)


class SimpleDNNGenerator(adanet.subnetwork.Generator):
  """Generates a two DNN subnetworks at each iteration.

  The first DNN has an identical shape to the most recently added subnetwork
  in `previous_ensemble`. The second has the same shape plus one more dense
  layer on top. This is similar to the adaptive network presented in Figure 2 of
  [Cortes et al. ICML 2017](https://arxiv.org/abs/1607.01097), without the
  connections to hidden layers of networks from previous iterations.
  """

  def __init__(self,
               optimizer,
               layer_size=64,
               learn_mixture_weights=False,
               seed=None):
    """Initializes a DNN `Generator`.

    Args:
      optimizer: An `Optimizer` instance for training both the subnetwork and
        the mixture weights.
      layer_size: Number of nodes in each hidden layer of the subnetwork
        candidates. Note that this parameter is ignored in a DNN with no hidden
        layers.
      learn_mixture_weights: Whether to solve a learning problem to find the
        best mixture weights, or use their default value according to the
        mixture weight type. When `False`, the subnetworks will return a no_op
        for the mixture weight train op.
      seed: A random seed.

    Returns:
      An instance of `Generator`.
    """

    self._seed = seed
    self._dnn_builder_fn = functools.partial(
        _SimpleDNNBuilder,
        optimizer=optimizer,
        layer_size=layer_size,
        learn_mixture_weights=learn_mixture_weights)

  def generate_candidates(self, previous_ensemble, iteration_number,
                          previous_ensemble_reports, all_reports):
    """See `adanet.subnetwork.Generator`."""

    num_layers = 0
    seed = self._seed
    if previous_ensemble:
      num_layers = tf.contrib.util.constant_value(
          previous_ensemble.weighted_subnetworks[
              -1].subnetwork.persisted_tensors[_NUM_LAYERS_KEY])
    if seed is not None:
      seed += iteration_number
    return [
        self._dnn_builder_fn(num_layers=num_layers, seed=seed),
        self._dnn_builder_fn(num_layers=num_layers + 1, seed=seed),
    ]

# %%
LEARNING_RATE = 0.001  #@param {type:"number"}
TRAIN_STEPS = 60000  #@param {type:"integer"}
BATCH_SIZE = 32  #@param {type:"integer"}
LEARN_MIXTURE_WEIGHTS = False  #@param {type:"boolean"}
ADANET_LAMBDA = 0  #@param {type:"number"}
ADANET_ITERATIONS = 3  #@param {type:"integer"}

def train_and_evaluate(experiment_name, learn_mixture_weights=LEARN_MIXTURE_WEIGHTS,
                       adanet_lambda=ADANET_LAMBDA):
    """Trains an `adanet.Estimator` to predict housing prices."""

    model_dir = os.path.join(LOG_DIR, experiment_name)
    print(model_dir)
    estimator = adanet.Estimator(
      # Since we are predicting housing prices, we'll use a regression
      # head that optimizes for MSE.
      head=tf.contrib.estimator.regression_head(
          loss_reduction=tf.losses.Reduction.SUM_OVER_BATCH_SIZE),
        model_dir  = model_dir , 
      # Define the generator, which defines our search space of subnetworks
      # to train as candidates to add to the final AdaNet model.
      subnetwork_generator=SimpleDNNGenerator(
          optimizer=tf.train.RMSPropOptimizer(learning_rate=LEARNING_RATE),
          learn_mixture_weights=learn_mixture_weights,
          seed=RANDOM_SEED),

      # Lambda is a the strength of complexity regularization. A larger
      # value will penalize more complex subnetworks.
      adanet_lambda=adanet_lambda,

      # The number of train steps per iteration.
      max_iteration_steps=TRAIN_STEPS // ADANET_ITERATIONS,

      # The evaluator will evaluate the model on the full training set to
      # compute the overall AdaNet loss (train loss + complexity
      # regularization) to select the best candidate to include in the
      # final AdaNet model.
      evaluator=adanet.Evaluator(
          input_fn=input_fn("train", training=False, batch_size=BATCH_SIZE)),

      # Configuration for Estimators.
      config=tf.estimator.RunConfig(
          save_summary_steps=5000,
          save_checkpoints_steps=5000,
          tf_random_seed=RANDOM_SEED,
          model_dir=model_dir) 
    )

  # Train and evaluate using using the tf.estimator tooling.
    train_spec = tf.estimator.TrainSpec(
        input_fn=input_fn("train", training=True, batch_size=BATCH_SIZE),
        max_steps=TRAIN_STEPS)
    eval_spec = tf.estimator.EvalSpec(
        input_fn=input_fn("test", training=False, batch_size=BATCH_SIZE),
        steps=None,
        start_delay_secs=1,
        throttle_secs=30,
  )
    return [tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec) , estimator]


def ensemble_architecture(result):
    """Extracts the ensemble architecture from evaluation results."""

    architecture = result["architecture/adanet/ensembles"]
    # The architecture is a serialized Summary proto for TensorBoard.
    summary_proto = tf.summary.Summary.FromString(architecture)
    return summary_proto.value[0].tensor.string_val[0]

# %%
# results, _ , estimator
results = train_and_evaluate("uniform_average_ensemble_baseline")
print("Loss:", results[0]["average_loss"])
print("Architecture:", ensemble_architecture(results[0]))
# Out:
# W1228 23:13:02.655593 140099870877440 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# /tmp/models/uniform_average_ensemble_baseline
# W1228 23:13:03.698187 140099870877440 estimator.py:653] The following arguments have been moved to `adanet.ensemble.ComplexityRegularizedEnsembler` which can be specified in the `ensemblers` argument: ['adanet_lambda']
# W1228 23:13:03.712658 140099870877440 deprecation.py:323] From /root/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W1228 23:13:03.748080 140099870877440 deprecation.py:323] From /root/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/data/util/random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1228 23:13:03.758502 140099870877440 deprecation.py:323] From <ipython-input-7-48abf98e4055>:24: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W1228 23:13:03.805095 140099870877440 deprecation.py:323] From <ipython-input-8-fb8e373057d9>:41: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1228 23:13:03.807863 140099870877440 deprecation.py:323] From <ipython-input-8-fb8e373057d9>:53: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# W1228 23:13:03.810785 140099870877440 deprecation.py:323] From /root/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1228 23:13:03.831907 140099870877440 deprecation.py:506] From <ipython-input-8-fb8e373057d9>:60: calling Subnetwork.__new__ (from adanet.subnetwork.generator) with persisted_tensors is deprecated and will be removed in a future version.
# Instructions for updating:
# `persisted_tensors` is deprecated, please use `shared` instead.
# W1228 23:13:03.934525 140099870877440 deprecation.py:506] From /root/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W1228 23:13:04.300338 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:13:04.413054 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:13:36.509018 140099870877440 deprecation.py:323] From /root/anaconda3/lib/python3.6/site-packages/adanet/core/estimator.py:1408: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1228 23:13:36.510939 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# W1228 23:14:07.423758 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# W1228 23:14:39.415736 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# W1228 23:15:09.268241 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# W1228 23:15:12.999355 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# W1228 23:15:14.311923 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:15:14.470412 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:15:15.524506 140099870877440 deprecation.py:323] From /root/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# W1228 23:15:17.762977 140099870877440 deprecation.py:323] From /root/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# W1228 23:15:19.309566 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:15:19.464692 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:17:28.766331 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# W1228 23:17:30.633637 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:17:30.809806 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:17:37.602285 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.
# W1228 23:17:37.785262 140099870877440 ensemble_builder.py:490] The `build_mixture_weights_train_op` method is deprecated. Please use the `Ensembler#build_train_op` instead.

# %%
output = results[1].predict(input_fn= input_fn("train", training=False, batch_size=1))
output = list(output)
# Out:
# W1229 00:02:16.931987 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.

# %%
output
# Out:
# [{'predictions': array([2.849688], dtype=float32)},
#  {'predictions': array([3.8059416], dtype=float32)},
#  {'predictions': array([4.053503], dtype=float32)},
#  {'predictions': array([3.129919], dtype=float32)},
#  {'predictions': array([3.0716314], dtype=float32)},
#  {'predictions': array([3.049693], dtype=float32)},
#  {'predictions': array([2.5576077], dtype=float32)},
#  {'predictions': array([2.787211], dtype=float32)},
#  {'predictions': array([2.907915], dtype=float32)},
#  {'predictions': array([2.7754586], dtype=float32)},
#  {'predictions': array([2.5944326], dtype=float32)},
#  {'predictions': array([2.9241042], dtype=float32)},
#  {'predictions': array([3.2199223], dtype=float32)},
#  {'predictions': array([3.0422444], dtype=float32)},
#  {'predictions': array([2.8911166], dtype=float32)},
#  {'predictions': array([2.3533616], dtype=float32)},
#  {'predictions': array([4.087616], dtype=float32)},
#  {'predictions': array([3.3103914], dtype=float32)},
#  {'predictions': array([3.2928736], dtype=float32)},
#  {'predictions': array([3.2710187], dtype=float32)},
#  {'predictions': array([2.5186281], dtype=float32)},
#  {'predictions': array([3.495513], dtype=float32)},
#  {'predictions': array([3.6039293], dtype=float32)},
#  {'predictions': array([3.2993035], dtype=float32)},
#  {'predictions': array([3.0933552], dtype=float32)},
#  {'predictions': array([2.6902266], dtype=float32)},
#  {'predictions': array([3.1350923], dtype=float32)},
#  {'predictions': array([3.567408], dtype=float32)},
#  {'predictions': array([2.9304938], dtype=float32)},
#  {'predictions': array([3.017491], dtype=float32)},
#  {'predictions': array([3.2491052], dtype=float32)},
#  {'predictions': array([2.9675865], dtype=float32)},
#  {'predictions': array([2.8446715], dtype=float32)},
#  {'predictions': array([3.2362819], dtype=float32)},
#  {'predictions': array([3.6338196], dtype=float32)},
#  {'predictions': array([3.2841833], dtype=float32)},
#  {'predictions': array([2.7874346], dtype=float32)},
#  {'predictions': array([2.7694252], dtype=float32)},
#  {'predictions': array([3.1997547], dtype=float32)},
#  {'predictions': array([3.1476781], dtype=float32)},
#  {'predictions': array([2.7962642], dtype=float32)},
#  {'predictions': array([3.3130674], dtype=float32)},
#  {'predictions': array([3.206628], dtype=float32)},
#  {'predictions': array([2.851023], dtype=float32)},
#  {'predictions': array([2.6647325], dtype=float32)},
#  {'predictions': array([2.921545], dtype=float32)},
#  {'predictions': array([3.0246096], dtype=float32)},
#  {'predictions': array([3.091312], dtype=float32)},
#  {'predictions': array([3.5970464], dtype=float32)},
#  {'predictions': array([2.7842321], dtype=float32)},
#  {'predictions': array([3.1327584], dtype=float32)},
#  {'predictions': array([2.5000596], dtype=float32)},
#  {'predictions': array([3.601293], dtype=float32)},
#  {'predictions': array([3.2818923], dtype=float32)},
#  {'predictions': array([3.1565375], dtype=float32)},
#  {'predictions': array([3.1403556], dtype=float32)},
#  {'predictions': array([2.7407622], dtype=float32)},
#  {'predictions': array([2.6391754], dtype=float32)},
#  {'predictions': array([3.547431], dtype=float32)},
#  {'predictions': array([3.4713528], dtype=float32)},
#  {'predictions': array([3.1202922], dtype=float32)},
#  {'predictions': array([3.2736046], dtype=float32)},
#  {'predictions': array([2.7517228], dtype=float32)},
#  {'predictions': array([3.0542798], dtype=float32)},
#  {'predictions': array([2.8011565], dtype=float32)},
#  {'predictions': array([2.8121297], dtype=float32)},
#  {'predictions': array([2.8691106], dtype=float32)},
#  {'predictions': array([2.4432259], dtype=float32)},
#  {'predictions': array([2.3035102], dtype=float32)},
#  {'predictions': array([3.0803165], dtype=float32)},
#  {'predictions': array([3.1319351], dtype=float32)},
#  {'predictions': array([2.6003683], dtype=float32)},
#  {'predictions': array([3.6718502], dtype=float32)},
#  {'predictions': array([3.000697], dtype=float32)},
#  {'predictions': array([2.7047045], dtype=float32)},
#  {'predictions': array([2.8471694], dtype=float32)},
#  {'predictions': array([2.348041], dtype=float32)},
#  {'predictions': array([2.9008884], dtype=float32)},
#  {'predictions': array([2.9426541], dtype=float32)},
#  {'predictions': array([2.7124066], dtype=float32)},
#  {'predictions': array([3.435568], dtype=float32)},
#  {'predictions': array([3.8653045], dtype=float32)},
#  {'predictions': array([3.0486465], dtype=float32)},
#  {'predictions': array([3.2177444], dtype=float32)},
#  {'predictions': array([3.1426487], dtype=float32)},
#  {'predictions': array([3.1660333], dtype=float32)},
#  {'predictions': array([2.743433], dtype=float32)},
#  {'predictions': array([3.9117742], dtype=float32)},
#  {'predictions': array([2.735265], dtype=float32)},
#  {'predictions': array([2.7430062], dtype=float32)},
#  {'predictions': array([3.2735248], dtype=float32)},
#  {'predictions': array([3.9609368], dtype=float32)},
#  {'predictions': array([3.2397814], dtype=float32)},
#  {'predictions': array([3.7291367], dtype=float32)},
#  {'predictions': array([3.7164192], dtype=float32)},
#  {'predictions': array([3.145266], dtype=float32)},
#  {'predictions': array([3.579669], dtype=float32)},
#  {'predictions': array([3.2087402], dtype=float32)},
#  {'predictions': array([3.500667], dtype=float32)},
#  {'predictions': array([3.4452088], dtype=float32)},
#  {'predictions': array([3.8889527], dtype=float32)},
#  {'predictions': array([3.8380413], dtype=float32)},
#  {'predictions': array([3.1321392], dtype=float32)},
#  {'predictions': array([3.382518], dtype=float32)},
#  {'predictions': array([2.8433955], dtype=float32)},
#  {'predictions': array([3.3367727], dtype=float32)},
#  {'predictions': array([2.7332506], dtype=float32)},
#  {'predictions': array([3.146841], dtype=float32)},
#  {'predictions': array([2.6775336], dtype=float32)},
#  {'predictions': array([3.184097], dtype=float32)},
#  {'predictions': array([3.033565], dtype=float32)},
#  {'predictions': array([3.9609213], dtype=float32)},
#  {'predictions': array([3.226141], dtype=float32)},
#  {'predictions': array([3.0223055], dtype=float32)},
#  {'predictions': array([3.312077], dtype=float32)},
#  {'predictions': array([3.5599627], dtype=float32)},
#  {'predictions': array([2.837314], dtype=float32)},
#  {'predictions': array([2.9911242], dtype=float32)},
#  {'predictions': array([2.9694676], dtype=float32)},
#  {'predictions': array([3.1268847], dtype=float32)},
#  {'predictions': array([3.4031935], dtype=float32)},
#  {'predictions': array([3.0462914], dtype=float32)},
#  {'predictions': array([2.329586], dtype=float32)},
#  {'predictions': array([3.7456312], dtype=float32)},
#  {'predictions': array([2.4115837], dtype=float32)},
#  {'predictions': array([2.6782315], dtype=float32)},
#  {'predictions': array([3.1696353], dtype=float32)},
#  {'predictions': array([3.5499969], dtype=float32)},
#  {'predictions': array([3.4541092], dtype=float32)},
#  {'predictions': array([3.2334526], dtype=float32)},
#  {'predictions': array([3.1331096], dtype=float32)},
#  {'predictions': array([3.0522895], dtype=float32)},
#  {'predictions': array([3.5893064], dtype=float32)},
#  {'predictions': array([3.4925919], dtype=float32)},
#  {'predictions': array([3.2223506], dtype=float32)},
#  {'predictions': array([3.0575628], dtype=float32)},
#  {'predictions': array([2.5634427], dtype=float32)},
#  {'predictions': array([4.0452347], dtype=float32)},
#  {'predictions': array([3.1782515], dtype=float32)},
#  {'predictions': array([1.9326942], dtype=float32)},
#  {'predictions': array([2.808167], dtype=float32)},
#  {'predictions': array([3.1069098], dtype=float32)},
#  {'predictions': array([2.8251996], dtype=float32)},
#  {'predictions': array([3.1344953], dtype=float32)},
#  {'predictions': array([3.2591488], dtype=float32)},
#  {'predictions': array([3.210089], dtype=float32)},
#  {'predictions': array([3.2430804], dtype=float32)},
#  {'predictions': array([3.0557637], dtype=float32)},
#  {'predictions': array([2.9053435], dtype=float32)},
#  {'predictions': array([3.308323], dtype=float32)},
#  {'predictions': array([2.7324255], dtype=float32)},
#  {'predictions': array([3.338306], dtype=float32)},
#  {'predictions': array([3.1835446], dtype=float32)},
#  {'predictions': array([2.8586535], dtype=float32)},
#  {'predictions': array([3.1979702], dtype=float32)},
#  {'predictions': array([3.0654662], dtype=float32)},
#  {'predictions': array([2.1627285], dtype=float32)},
#  {'predictions': array([3.3252857], dtype=float32)},
#  {'predictions': array([3.277909], dtype=float32)},
#  {'predictions': array([3.209176], dtype=float32)},
#  {'predictions': array([3.0975049], dtype=float32)},
#  {'predictions': array([3.3540335], dtype=float32)},
#  {'predictions': array([3.0536265], dtype=float32)},
#  {'predictions': array([3.6091185], dtype=float32)},
#  {'predictions': array([3.2228856], dtype=float32)},
#  {'predictions': array([3.2947426], dtype=float32)},
#  {'predictions': array([3.1659844], dtype=float32)},
#  {'predictions': array([3.3114939], dtype=float32)},
#  {'predictions': array([3.410655], dtype=float32)},
#  {'predictions': array([2.8315606], dtype=float32)},
#  {'predictions': array([3.4245088], dtype=float32)},
#  {'predictions': array([3.367134], dtype=float32)},
#  {'predictions': array([3.1089454], dtype=float32)},
#  {'predictions': array([3.0000634], dtype=float32)},
#  {'predictions': array([3.1245253], dtype=float32)},
#  {'predictions': array([3.0321226], dtype=float32)},
#  {'predictions': array([2.4187014], dtype=float32)},
#  {'predictions': array([3.3039842], dtype=float32)},
#  {'predictions': array([2.7601514], dtype=float32)},
#  {'predictions': array([3.2367573], dtype=float32)},
#  {'predictions': array([2.908426], dtype=float32)},
#  {'predictions': array([3.1208143], dtype=float32)},
#  {'predictions': array([3.5153975], dtype=float32)},
#  {'predictions': array([3.492661], dtype=float32)},
#  {'predictions': array([3.16094], dtype=float32)},
#  {'predictions': array([2.3983681], dtype=float32)},
#  {'predictions': array([3.1163135], dtype=float32)},
#  {'predictions': array([3.0540493], dtype=float32)},
#  {'predictions': array([3.1856403], dtype=float32)},
#  {'predictions': array([3.198316], dtype=float32)},
#  {'predictions': array([2.8101768], dtype=float32)},
#  {'predictions': array([3.919932], dtype=float32)},
#  {'predictions': array([3.2663767], dtype=float32)},
#  {'predictions': array([3.6206248], dtype=float32)},
#  {'predictions': array([3.15736], dtype=float32)},
#  {'predictions': array([2.7349815], dtype=float32)},
#  {'predictions': array([3.5159714], dtype=float32)},
#  {'predictions': array([2.4911032], dtype=float32)},
#  {'predictions': array([3.2588184], dtype=float32)},
#  {'predictions': array([3.1692286], dtype=float32)},
#  {'predictions': array([3.2633603], dtype=float32)},
#  {'predictions': array([2.676875], dtype=float32)},
#  {'predictions': array([3.2758348], dtype=float32)},
#  {'predictions': array([3.2927933], dtype=float32)},
#  {'predictions': array([2.9949005], dtype=float32)},
#  {'predictions': array([2.9787607], dtype=float32)},
#  {'predictions': array([2.7625363], dtype=float32)},
#  {'predictions': array([3.1467175], dtype=float32)},
#  {'predictions': array([3.0068254], dtype=float32)},
#  {'predictions': array([3.1272163], dtype=float32)},
#  {'predictions': array([3.3074203], dtype=float32)},
#  {'predictions': array([2.7643628], dtype=float32)},
#  {'predictions': array([3.2740865], dtype=float32)},
#  {'predictions': array([3.2156844], dtype=float32)},
#  {'predictions': array([2.6128857], dtype=float32)},
#  {'predictions': array([3.3899155], dtype=float32)},
#  {'predictions': array([3.1640694], dtype=float32)},
#  {'predictions': array([3.0685825], dtype=float32)},
#  {'predictions': array([3.2929358], dtype=float32)},
#  {'predictions': array([3.2309768], dtype=float32)},
#  {'predictions': array([2.9360607], dtype=float32)},
#  {'predictions': array([2.5860467], dtype=float32)},
#  {'predictions': array([3.1805744], dtype=float32)},
#  {'predictions': array([3.1355414], dtype=float32)},
#  {'predictions': array([3.2781758], dtype=float32)},
#  {'predictions': array([3.618887], dtype=float32)},
#  {'predictions': array([3.541855], dtype=float32)},
#  {'predictions': array([3.066947], dtype=float32)},
#  {'predictions': array([3.365943], dtype=float32)},
#  {'predictions': array([3.4170942], dtype=float32)},
#  {'predictions': array([3.506205], dtype=float32)},
#  {'predictions': array([2.893694], dtype=float32)},
#  {'predictions': array([3.2220118], dtype=float32)},
#  {'predictions': array([3.8168385], dtype=float32)},
#  {'predictions': array([3.241913], dtype=float32)},
#  {'predictions': array([3.304458], dtype=float32)},
#  {'predictions': array([2.7317057], dtype=float32)},
#  {'predictions': array([2.8582604], dtype=float32)},
#  {'predictions': array([3.0873728], dtype=float32)},
#  {'predictions': array([2.852711], dtype=float32)},
#  {'predictions': array([2.865714], dtype=float32)},
#  {'predictions': array([2.3787992], dtype=float32)},
#  {'predictions': array([3.2017593], dtype=float32)},
#  {'predictions': array([3.1069446], dtype=float32)},
#  {'predictions': array([3.2024932], dtype=float32)},
#  {'predictions': array([3.1100469], dtype=float32)},
#  {'predictions': array([3.5955808], dtype=float32)},
#  {'predictions': array([2.9478421], dtype=float32)},
#  {'predictions': array([2.0035777], dtype=float32)},
#  {'predictions': array([2.8638537], dtype=float32)},
#  {'predictions': array([2.7271595], dtype=float32)},
#  {'predictions': array([3.2219543], dtype=float32)},
#  {'predictions': array([2.5505424], dtype=float32)},
#  {'predictions': array([2.5789497], dtype=float32)},
#  {'predictions': array([2.7945921], dtype=float32)},
#  {'predictions': array([2.9361806], dtype=float32)},
#  {'predictions': array([3.1004739], dtype=float32)},
#  {'predictions': array([3.472968], dtype=float32)},
#  {'predictions': array([2.7583463], dtype=float32)},
#  {'predictions': array([3.5823379], dtype=float32)},
#  {'predictions': array([3.8010602], dtype=float32)},
#  {'predictions': array([2.790124], dtype=float32)},
#  {'predictions': array([3.2522316], dtype=float32)},
#  {'predictions': array([3.448163], dtype=float32)},
#  {'predictions': array([3.2298496], dtype=float32)},
#  {'predictions': array([3.0116105], dtype=float32)},
#  {'predictions': array([3.0007567], dtype=float32)},
#  {'predictions': array([3.5603828], dtype=float32)},
#  {'predictions': array([3.0889442], dtype=float32)},
#  {'predictions': array([3.3107421], dtype=float32)},
#  {'predictions': array([2.8827379], dtype=float32)},
#  {'predictions': array([3.3087316], dtype=float32)},
#  {'predictions': array([3.4912255], dtype=float32)},
#  {'predictions': array([3.1700256], dtype=float32)},
#  {'predictions': array([3.2171736], dtype=float32)},
#  {'predictions': array([3.2400477], dtype=float32)},
#  {'predictions': array([3.592232], dtype=float32)},
#  {'predictions': array([3.3428626], dtype=float32)},
#  {'predictions': array([3.0603642], dtype=float32)},
#  {'predictions': array([3.7106845], dtype=float32)},
#  {'predictions': array([2.9764001], dtype=float32)},
#  {'predictions': array([3.0738611], dtype=float32)},
#  {'predictions': array([2.3666039], dtype=float32)},
#  {'predictions': array([3.3067198], dtype=float32)},
#  {'predictions': array([2.3443637], dtype=float32)},
#  {'predictions': array([2.6532862], dtype=float32)},
#  {'predictions': array([2.3582046], dtype=float32)},
#  {'predictions': array([2.6693656], dtype=float32)},
#  {'predictions': array([2.7477112], dtype=float32)},
#  {'predictions': array([3.2254124], dtype=float32)},
#  {'predictions': array([3.8224895], dtype=float32)},
#  {'predictions': array([2.894948], dtype=float32)},
#  {'predictions': array([3.0686047], dtype=float32)},
#  {'predictions': array([2.92456], dtype=float32)},
#  {'predictions': array([3.1229362], dtype=float32)},
#  {'predictions': array([3.1641107], dtype=float32)},
#  {'predictions': array([3.645008], dtype=float32)},
#  {'predictions': array([2.6139648], dtype=float32)},
#  {'predictions': array([3.3231993], dtype=float32)},
#  {'predictions': array([2.5127792], dtype=float32)},
#  {'predictions': array([3.1090014], dtype=float32)},
#  {'predictions': array([2.942404], dtype=float32)},
#  {'predictions': array([3.0222857], dtype=float32)},
#  {'predictions': array([3.5808358], dtype=float32)},
#  {'predictions': array([2.8367825], dtype=float32)},
#  {'predictions': array([3.066741], dtype=float32)},
#  {'predictions': array([3.6371675], dtype=float32)},
#  {'predictions': array([3.1800416], dtype=float32)},
#  {'predictions': array([3.0903924], dtype=float32)},
#  {'predictions': array([3.534668], dtype=float32)},
#  {'predictions': array([3.3464694], dtype=float32)},
#  {'predictions': array([3.0880814], dtype=float32)},
#  {'predictions': array([3.2788537], dtype=float32)},
#  {'predictions': array([2.3659525], dtype=float32)},
#  {'predictions': array([3.884101], dtype=float32)},
#  {'predictions': array([3.0507135], dtype=float32)},
#  {'predictions': array([3.013384], dtype=float32)},
#  {'predictions': array([3.9375603], dtype=float32)},
#  {'predictions': array([3.9670413], dtype=float32)},
#  {'predictions': array([3.035084], dtype=float32)},
#  {'predictions': array([3.0763836], dtype=float32)},
#  {'predictions': array([3.9084845], dtype=float32)},
#  {'predictions': array([2.9692636], dtype=float32)},
#  {'predictions': array([3.174204], dtype=float32)},
#  {'predictions': array([3.0465748], dtype=float32)},
#  {'predictions': array([3.7540517], dtype=float32)},
#  {'predictions': array([3.138699], dtype=float32)},
#  {'predictions': array([3.1283865], dtype=float32)},
#  {'predictions': array([2.805018], dtype=float32)},
#  {'predictions': array([2.9858456], dtype=float32)},
#  {'predictions': array([3.224767], dtype=float32)},
#  {'predictions': array([3.1444092], dtype=float32)},
#  {'predictions': array([3.5253298], dtype=float32)},
#  {'predictions': array([3.2799826], dtype=float32)},
#  {'predictions': array([2.952582], dtype=float32)},
#  {'predictions': array([2.8315387], dtype=float32)},
#  {'predictions': array([3.5835907], dtype=float32)},
#  {'predictions': array([3.6279001], dtype=float32)},
#  {'predictions': array([2.549614], dtype=float32)},
#  {'predictions': array([3.053409], dtype=float32)},
#  {'predictions': array([3.0452218], dtype=float32)},
#  {'predictions': array([2.950113], dtype=float32)},
#  {'predictions': array([3.4020114], dtype=float32)},
#  {'predictions': array([3.424254], dtype=float32)},
#  {'predictions': array([3.9733634], dtype=float32)},
#  {'predictions': array([4.033064], dtype=float32)},
#  {'predictions': array([3.287483], dtype=float32)},
#  {'predictions': array([2.5887055], dtype=float32)},
#  {'predictions': array([3.803061], dtype=float32)},
#  {'predictions': array([3.9889061], dtype=float32)},
#  {'predictions': array([3.1786048], dtype=float32)},
#  {'predictions': array([3.1625352], dtype=float32)},
#  {'predictions': array([3.366888], dtype=float32)},
#  {'predictions': array([3.424814], dtype=float32)},
#  {'predictions': array([4.0383043], dtype=float32)},
#  {'predictions': array([3.130629], dtype=float32)},
#  {'predictions': array([3.2464082], dtype=float32)},
#  {'predictions': array([3.243825], dtype=float32)},
#  {'predictions': array([2.927167], dtype=float32)},
#  {'predictions': array([3.1619062], dtype=float32)},
#  {'predictions': array([3.0937438], dtype=float32)},
#  {'predictions': array([3.796853], dtype=float32)},
#  {'predictions': array([3.1292953], dtype=float32)},
#  {'predictions': array([3.5345263], dtype=float32)},
#  {'predictions': array([3.080731], dtype=float32)},
#  {'predictions': array([3.0873384], dtype=float32)},
#  {'predictions': array([3.4781597], dtype=float32)},
#  {'predictions': array([3.1448345], dtype=float32)},
#  {'predictions': array([2.9743004], dtype=float32)},
#  {'predictions': array([3.0680501], dtype=float32)},
#  {'predictions': array([2.9459348], dtype=float32)},
#  {'predictions': array([2.8986216], dtype=float32)},
#  {'predictions': array([3.3423839], dtype=float32)},
#  {'predictions': array([3.2570558], dtype=float32)},
#  {'predictions': array([3.3637886], dtype=float32)},
#  {'predictions': array([3.6976504], dtype=float32)},
#  {'predictions': array([3.2401], dtype=float32)},
#  {'predictions': array([2.9096854], dtype=float32)},
#  {'predictions': array([3.3542032], dtype=float32)},
#  {'predictions': array([3.5104046], dtype=float32)},
#  {'predictions': array([3.238402], dtype=float32)},
#  {'predictions': array([2.9374318], dtype=float32)},
#  {'predictions': array([3.0012257], dtype=float32)},
#  {'predictions': array([3.4412582], dtype=float32)},
#  {'predictions': array([3.0030413], dtype=float32)},
#  {'predictions': array([3.2212434], dtype=float32)},
#  {'predictions': array([2.802176], dtype=float32)},
#  {'predictions': array([3.3390586], dtype=float32)},
#  {'predictions': array([3.453637], dtype=float32)},
#  {'predictions': array([2.833058], dtype=float32)},
#  {'predictions': array([2.5090475], dtype=float32)},
#  {'predictions': array([3.241733], dtype=float32)},
#  {'predictions': array([3.2562761], dtype=float32)},
#  {'predictions': array([3.0061972], dtype=float32)},
#  {'predictions': array([2.9392922], dtype=float32)},
#  {'predictions': array([2.1844301], dtype=float32)},
#  {'predictions': array([2.523688], dtype=float32)},
#  {'predictions': array([3.2249637], dtype=float32)},
#  {'predictions': array([2.6413472], dtype=float32)},
#  {'predictions': array([3.0398996], dtype=float32)},
#  {'predictions': array([3.3440602], dtype=float32)},
#  {'predictions': array([3.0822365], dtype=float32)},
#  {'predictions': array([3.025285], dtype=float32)},
#  {'predictions': array([3.4572313], dtype=float32)}]

# %%
input_column = tf.feature_column.numeric_column("x", shape=(13,))
serving_input_fn = tf.estimator.export.build_parsing_serving_input_receiver_fn(
  tf.feature_column.make_parse_example_spec([input_column]))

# %%
model_dir = '/tmp/models/uniform_average_ensemble_baseline/'
results[1].export_saved_model(export_dir_base = model_dir , 
                              serving_input_receiver_fn = serving_input_fn ,
                              checkpoint_path = None , 
                              experimental_mode='infer'
                             )
# Out:
# W1228 23:56:27.215113 140099870877440 queue_runner_impl.py:471] `tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# b'/tmp/models/uniform_average_ensemble_baseline/1577544987'

# %%
from tensorflow.contrib import predictor
path ="/tmp/models/uniform_average_ensemble_baseline/1577544987/"
predict_fn = predictor.from_saved_model(path)

# %%
predict_fn
# Out:
# SavedModelPredictor with feed tensors {'inputs': <tf.Tensor 'input_example_tensor:0' shape=(?,) dtype=string>} and fetch_tensors {'outputs': <tf.Tensor 'adanet/iteration_2/best_export_outputs/strided_slice_1:0' shape=(?, 1) dtype=float32>}

# %%
from tensorflow.contrib import slim
path ="/tmp/models/uniform_average_ensemble_baseline/1577542872/"
#Model = tf.saved_model.load(path, )
with tf.Session(graph=tf.Graph()) as sess:
    tf.saved_model.load(sess, ["serve"], export_dir= path)
    graph = tf.get_default_graph()
    print(graph.get_operations())
# Out:
# [<tf.Operation 'global_step/Initializer/zeros' type=Const>, <tf.Operation 'global_step' type=VariableV2>, <tf.Operation 'global_step/Assign' type=Assign>, <tf.Operation 'global_step/read' type=Identity>, <tf.Operation 'input_example_tensor' type=Placeholder>, <tf.Operation 'ParseExample/Const' type=Const>, <tf.Operation 'ParseExample/ParseExample/names' type=Const>, <tf.Operation 'ParseExample/ParseExample/dense_keys_0' type=Const>, <tf.Operation 'ParseExample/ParseExample' type=ParseExample>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/step/Initializer/zeros' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/step' type=VariableV2>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/step/Assign' type=Assign>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/step/read' type=Identity>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/Const' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Initializer/random_uniform/shape' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Initializer/random_uniform/min' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Initializer/random_uniform/max' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Initializer/random_uniform/RandomUniform' type=RandomUniform>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Initializer/random_uniform/sub' type=Sub>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Initializer/random_uniform/mul' type=Mul>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Initializer/random_uniform' type=Add>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel' type=VariableV2>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/Assign' type=Assign>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel/read' type=Identity>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/bias/Initializer/zeros' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/bias' type=VariableV2>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/bias/Assign' type=Assign>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/bias/read' type=Identity>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/MatMul' type=MatMul>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/BiasAdd' type=BiasAdd>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/Relu' type=Relu>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Initializer/random_uniform/shape' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Initializer/random_uniform/min' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Initializer/random_uniform/max' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Initializer/random_uniform/RandomUniform' type=RandomUniform>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Initializer/random_uniform/sub' type=Sub>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Initializer/random_uniform/mul' type=Mul>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Initializer/random_uniform' type=Add>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel' type=VariableV2>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/Assign' type=Assign>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel/read' type=Identity>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/bias/Initializer/zeros' type=Const>, <tf.Operation 'adanet/iteration_0/subnetwork_t0_1_layer_dnn/dens ...

# %%
import numpy as np
np_value
# Out:
# [0.014287446608069455,
#  4.110873864173311,
#  1.3686394258811698,
#  0.0,
#  0.33718626735486995,
#  2.0286744246261827,
#  2.9856819377004897,
#  1.9767995497079562,
#  0.6931471805599453,
#  5.583496308781699,
#  2.8094026953624978,
#  5.934100229718411,
#  1.682688374173693]

# %%
exported_path = "/tmp/models/uniform_average_ensemble_baseline/1577544987/"
predictor= tf.contrib.predictor.from_saved_model(exported_path)
for x_value in x_train.tolist() : 
    np_value = np.log(np.array(x_value)+1).tolist()
    model_input= tf.train.Example(features=tf.train.Features(feature={
            'x': tf.train.Feature(float_list=tf.train.FloatList(value= np_value ))        
            })) 
    model_input=model_input.SerializeToString()
    output_dict= predictor({"inputs":[model_input]})
    print(output_dict["outputs"][0])
# Out:
# [2.849688]
# [3.8059416]
# [4.053503]
# [3.129919]
# [3.0716314]
# [3.049693]
# [2.5576077]
# [2.787211]
# [2.907915]
# [2.7754586]
# [2.5944326]
# [2.9241042]
# [3.2199223]
# [3.0422444]
# [2.8911166]
# [2.3533616]
# [4.087616]
# [3.3103914]
# [3.2928736]
# [3.2710187]
# [2.5186281]
# [3.495513]
# [3.6039293]
# [3.2993035]
# [3.0933552]
# [2.6902266]
# [3.1350923]
# [3.567408]
# [2.9304938]
# [3.017491]
# [3.2491052]
# [2.9675865]
# [2.8446715]
# [3.2362819]
# [3.6338196]
# [3.2841833]
# [2.7874346]
# [2.7694252]
# [3.1997547]
# [3.1476781]
# [2.7962642]
# [3.3130674]
# [3.206628]
# [2.851023]
# [2.6647325]
# [2.921545]
# [3.0246096]
# [3.091312]
# [3.5970464]
# [2.7842321]
# [3.1327584]
# [2.5000596]
# [3.601293]
# [3.2818923]
# [3.1565375]
# [3.1403556]
# [2.7407622]
# [2.6391754]
# [3.547431]
# [3.4713528]
# [3.1202922]
# [3.2736046]
# [2.7517228]
# [3.0542798]
# [2.8011565]
# [2.8121297]
# [2.8691106]
# [2.4432259]
# [2.3035102]
# [3.0803165]
# [3.1319351]
# [2.6003683]
# [3.6718502]
# [3.000697]
# [2.7047045]
# [2.8471694]
# [2.348041]
# [2.9008884]
# [2.9426541]
# [2.7124066]
# [3.435568]
# [3.8653045]
# [3.0486465]
# [3.2177444]
# [3.1426487]
# [3.1660333]
# [2.743433]
# [3.9117742]
# [2.735265]
# [2.7430062]
# [3.2735248]
# [3.9609368]
# [3.2397814]
# [3.7291367]
# [3.7164192]
# [3.145266]
# [3.579669]
# [3.2087402]
# [3.500667]
# [3.4452088]
# [3.8889527]
# [3.8380413]
# [3.1321392]
# [3.382518]
# [2.8433955]
# [3.3367727]
# [2.7332506]
# [3.146841]
# [2.6775336]
# [3.184097]
# [3.033565]
# [3.9609213]
# [3.226141]
# [3.0223055]
# [3.312077]
# [3.5599627]
# [2.837314]
# [2.9911242]
# [2.9694676]
# [3.1268847]
# [3.4031935]
# [3.0462914]
# [2.329586]
# [3.7456312]
# [2.4115837]
# [2.6782315]
# [3.1696353]
# [3.5499969]
# [3.4541092]
# [3.2334526]
# [3.1331096]
# [3.0522895]
# [3.5893064]
# [3.4925919]
# [3.2223506]
# [3.0575628]
# [2.5634427]
# [4.0452347]
# [3.1782515]
# [1.9326942]
# [2.808167]
# [3.1069098]
# [2.8251996]
# [3.1344953]
# [3.2591488]
# [3.210089]
# [3.2430804]
# [3.0557637]
# [2.9053435]
# [3.308323]
# [2.7324255]
# [3.338306]
# [3.1835446]
# [2.8586535]
# [3.1979702]
# [3.0654662]
# [2.1627285]
# [3.3252857]
# [3.277909]
# [3.209176]
# [3.0975049]
# [3.3540335]
# [3.0536265]
# [3.6091185]
# [3.2228856]
# [3.2947426]
# [3.1659844]
# [3.3114939]
# [3.410655]
# [2.8315606]
# [3.4245088]
# [3.367134]
# [3.1089454]
# [3.0000634]
# [3.1245253]
# [3.0321226]
# [2.4187014]
# [3.3039842]
# [2.7601514]
# [3.2367573]
# [2.908426]
# [3.1208143]
# [3.5153975]
# [3.492661]
# [3.16094]
# [2.3983681]
# [3.1163135]
# [3.0540493]
# [3.1856403]
# [3.198316]
# [2.8101768]
# [3.919932]
# [3.2663767]
# [3.6206248]
# [3.15736]
# [2.7349815]
# [3.5159714]
# [2.4911032]
# [3.2588184]
# [3.1692286]
# [3.2633603]
# [2.676875]
# [3.2758348]
# [3.2927933]
# [2.9949005]
# [2.9787607]
# [2.7625363]
# [3.1467175]
# [3.0068254]
# [3.1272163]
# [3.3074203]
# [2.7643628]
# [3.2740865]
# [3.2156844]
# [2.6128857]
# [3.3899155]
# [3.1640694]
# [3.0685825]
# [3.2929358]
# [3.2309768]
# [2.9360607]
# [2.5860467]
# [3.1805744]
# [3.1355414]
# [3.2781758]
# [3.618887]
# [3.541855]
# [3.066947]
# [3.365943]
# [3.4170942]
# [3.506205]
# [2.893694]
# [3.2220118]
# [3.8168385]
# [3.241913]
# [3.304458]
# [2.7317057]
# [2.8582604]
# [3.0873728]
# [2.852711]
# [2.865714]
# [2.3787992]
# [3.2017593]
# [3.1069446]
# [3.2024932]
# [3.1100469]
# [3.5955808]
# [2.9478421]
# [2.0035777]
# [2.8638537]
# [2.7271595]
# [3.2219543]
# [2.5505424]
# [2.5789497]
# [2.7945921]
# [2.9361806]
# [3.1004739]
# [3.472968]
# [2.7583463]
# [3.5823379]
# [3.8010602]
# [2.790124]
# [3.2522316]
# [3.448163]
# [3.2298496]
# [3.0116105]
# [3.0007567]
# [3.5603828]
# [3.0889442]
# [3.3107421]
# [2.8827379]
# [3.3087316]
# [3.4912255]
# [3.1700256]
# [3.2171736]
# [3.2400477]
# [3.592232]
# [3.3428626]
# [3.0603642]
# [3.7106845]
# [2.9764001]
# [3.0738611]
# [2.3666039]
# [3.3067198]
# [2.3443637]
# [2.6532862]
# [2.3582046]
# [2.6693656]
# [2.7477112]
# [3.2254124]
# [3.8224895]
# [2.894948]
# [3.0686047]
# [2.92456]
# [3.1229362]
# [3.1641107]
# [3.645008]
# [2.6139648]
# [3.3231993]
# [2.5127792]
# [3.1090014]
# [2.942404]
# [3.0222857]
# [3.5808358]
# [2.8367825]
# [3.066741]
# [3.6371675]
# [3.1800416]
# [3.0903924]
# [3.534668]
# [3.3464694]
# [3.0880814]
# [3.2788537]
# [2.3659525]
# [3.884101]
# [3.0507135]
# [3.013384]
# [3.9375603]
# [3.9670413]
# [3.035084]
# [3.0763836]
# [3.9084845]
# [2.9692636]
# [3.174204]
# [3.0465748]
# [3.7540517]
# [3.138699]
# [3.1283865]
# [2.805018]
# [2.9858456]
# [3.224767]
# [3.1444092]
# [3.5253298]
# [3.2799826]
# [2.952582]
# [2.8315387]
# [3.5835907]
# [3.6279001]
# [2.549614]
# [3.053409]
# [3.0452218]
# [2.950113]
# [3.4020114]
# [3.424254]
# [3.9733634]
# [4.033064]
# [3.287483]
# [2.5887055]
# [3.803061]
# [3.9889061]
# [3.1786048]
# [3.1625352]
# [3.366888]
# [3.424814]
# [4.0383043]
# [3.130629]
# [3.2464082]
# [3.243825]
# [2.927167]
# [3.1619062]
# [3.0937438]
# [3.796853]
# [3.1292953]
# [3.5345263]
# [3.080731]
# [3.0873384]
# [3.4781597]
# [3.1448345]
# [2.9743004]
# [3.0680501]
# [2.9459348]
# [2.8986216]
# [3.3423839]
# [3.2570558]
# [3.3637886]
# [3.6976504]
# [3.2401]
# [2.9096854]
# [3.3542032]
# [3.5104046]
# [3.238402]
# [2.9374318]
# [3.0012257]
# [3.4412582]
# [3.0030413]
# [3.2212434]
# [2.802176]
# [3.3390586]
# [3.453637]
# [2.833058]
# [2.5090475]
# [3.241733]
# [3.2562761]
# [3.0061972]
# [2.9392922]
# [2.1844301]
# [2.523688]
# [3.2249637]
# [2.6413472]
# [3.0398996]
# [3.3440602]
# [3.0822365]
# [3.025285]
# [3.4572313]

# %% [markdown]
# https://stackoverflow.com/questions/52200016/tf-estimator-cant-load-pb-from-saved-model

# %%
with tf.Session() as sess:
    exported_path = "/tmp/models/uniform_average_ensemble_baseline/1577542872/"
    tf.saved_model.loader.load(sess, [tf.saved_model.tag_constants.SERVING], exported_path)
    predictor= tf.contrib.predictor.from_saved_model(exported_path)
    
    for x_value in x_train.tolist() : 
        model_input= tf.train.Example(features=tf.train.Features(feature={
                'x': tf.train.Feature(float_list=tf.train.FloatList(value=x_value))        
                })) 
        model_input=model_input.SerializeToString()
        output_dict= predictor({"inputs":[model_input]})
        print(output_dict)
# Out:
# {'outputs': array([[149.54388]], dtype=float32)}
# {'outputs': array([[144.15085]], dtype=float32)}
# {'outputs': array([[246.66365]], dtype=float32)}
# {'outputs': array([[127.57523]], dtype=float32)}
# {'outputs': array([[239.3547]], dtype=float32)}
# {'outputs': array([[141.01492]], dtype=float32)}
# {'outputs': array([[241.80632]], dtype=float32)}
# {'outputs': array([[164.99886]], dtype=float32)}
# {'outputs': array([[166.16196]], dtype=float32)}
# {'outputs': array([[169.87413]], dtype=float32)}
# {'outputs': array([[244.0774]], dtype=float32)}
# {'outputs': array([[203.5031]], dtype=float32)}
# {'outputs': array([[151.2827]], dtype=float32)}
# {'outputs': array([[243.30573]], dtype=float32)}
# {'outputs': array([[127.5654]], dtype=float32)}
# {'outputs': array([[198.67014]], dtype=float32)}
# {'outputs': array([[245.53656]], dtype=float32)}
# {'outputs': array([[140.65451]], dtype=float32)}
# {'outputs': array([[149.94504]], dtype=float32)}
# {'outputs': array([[153.27692]], dtype=float32)}
# {'outputs': array([[190.40477]], dtype=float32)}
# {'outputs': array([[134.40854]], dtype=float32)}
# {'outputs': array([[155.59592]], dtype=float32)}
# {'outputs': array([[143.96892]], dtype=float32)}
# {'outputs': array([[134.82275]], dtype=float32)}
# {'outputs': array([[242.31473]], dtype=float32)}
# {'outputs': array([[142.47292]], dtype=float32)}
# {'outputs': array([[136.71167]], dtype=float32)}
# {'outputs': array([[142.73325]], dtype=float32)}
# {'outputs': array([[154.20349]], dtype=float32)}
# {'outputs': array([[141.90213]], dtype=float32)}
# {'outputs': array([[240.59648]], dtype=float32)}
# {'outputs': array([[238.95456]], dtype=float32)}
# {'outputs': array([[125.618805]], dtype=float32)}
# {'outputs': array([[132.2474]], dtype=float32)}
# {'outputs': array([[132.76775]], dtype=float32)}
# {'outputs': array([[125.71369]], dtype=float32)}
# {'outputs': array([[140.8878]], dtype=float32)}
# {'outputs': array([[135.82968]], dtype=float32)}
# {'outputs': array([[150.00795]], dtype=float32)}
# {'outputs': array([[255.59933]], dtype=float32)}
# {'outputs': array([[120.7549]], dtype=float32)}
# {'outputs': array([[126.69413]], dtype=float32)}
# {'outputs': array([[247.9946]], dtype=float32)}
# {'outputs': array([[241.4808]], dtype=float32)}
# {'outputs': array([[149.23848]], dtype=float32)}
# {'outputs': array([[165.9011]], dtype=float32)}
# {'outputs': array([[142.1582]], dtype=float32)}
# {'outputs': array([[153.69838]], dtype=float32)}
# {'outputs': array([[241.80734]], dtype=float32)}
# {'outputs': array([[135.4999]], dtype=float32)}
# {'outputs': array([[200.72894]], dtype=float32)}
# {'outputs': array([[141.80295]], dtype=float32)}
# {'outputs': array([[128.22232]], dtype=float32)}
# {'outputs': array([[156.32944]], dtype=float32)}
# {'outputs': array([[128.3587]], dtype=float32)}
# {'outputs': array([[211.87502]], dtype=float32)}
# {'outputs': array([[210.91866]], dtype=float32)}
# {'outputs': array([[139.38614]], dtype=float32)}
# {'outputs': array([[130.61092]], dtype=float32)}
# {'outputs': array([[129.76141]], dtype=float32)}
# {'outputs': array([[137.8374]], dtype=float32)}
# {'outputs': array([[242.81796]], dtype=float32)}
# {'outputs': array([[158.77837]], dtype=float32)}
# {'outputs': array([[203.58495]], dtype=float32)}
# {'outputs': array([[217.27902]], dtype=float32)}
# {'outputs': array([[165.06403]], dtype=float32)}
# {'outputs': array([[240.4375]], dtype=float32)}
# {'outputs': array([[237.98045]], dtype=float32)}
# {'outputs': array([[147.81631]], dtype=float32)}
# {'outputs': array([[128.26173]], dtype=float32)}
# {'outputs': array([[221.34285]], dtype=float32)}
# {'outputs': array([[150.2475]], dtype=float32)}
# {'outputs': array([[145.14343]], dtype=float32)}
# {'outputs': array([[122.90979]], dtype=float32)}
# {'outputs': array([[155.93924]], dtype=float32)}
# {'outputs': array([[196.2503]], dtype=float32)}
# {'outputs': array([[166.78748]], dtype=float32)}
# {'outputs': array([[147.56622]], dtype=float32)}
# {'outputs': array([[165.03198]], dtype=float32)}
# {'outputs': array([[129.19788]], dtype=float32)}
# {'outputs': array([[140.65775]], dtype=float32)}
# {'outputs': array([[110.55091]], dtype=float32)}
# {'outputs': array([[138.64044]], dtype=float32)}
# {'outputs': array([[166.37527]], dtype=float32)}
# {'outputs': array([[126.80676]], dtype=float32)}
# {'outputs': array([[241.33456]], dtype=float32)}
# {'outputs': array([[136.3161]], dtype=float32)}
# {'outputs': array([[163.06683]], dtype=float32)}
# {'outputs': array([[190.56955]], dtype=float32)}
# {'outputs': array([[235.29945]], dtype=float32)}
# {'outputs': array([[135.52975]], dtype=float32)}
# {'outputs': array([[133.04492]], dtype=float32)}
# {'outputs': array([[139.87234]], dtype=float32)}
# {'outputs': array([[145.25972]], dtype=float32)}
# {'outputs': array([[133.22652]], dtype=float32)}
# {'outputs': array([[157.46501]], dtype=float32)}
# {'outputs': array([[133.06906]], dtype=float32)}
# {'outputs': array([[129.02026]], dtype=float32)}
# {'outputs': array([[134.97806]], dtype=float32)}
# {'outputs': array([[131.45993]], dtype=float32)}
# {'outputs': array([[141.42157]], dtype=float32)}
# {'outputs': array([[138.00873]], dtype=float32)}
# {'outputs': array([[117.680275]], dtype=float32)}
# {'outputs': array([[197.44955]], dtype=float32)}
# {'outputs': array([[130.00717]], dtype=float32)}
# {'outputs': array([[245.81198]], dtype=float32)}
# {'outputs': array([[128.1754]], dtype=float32)}
# {'outputs': array([[184.35179]], dtype=float32)}
# {'outputs': array([[147.65833]], dtype=float32)}
# {'outputs': array([[157.12689]], dtype=float32)}
# {'outputs': array([[158.15356]], dtype=float32)}
# {'outputs': array([[163.4669]], dtype=float32)}
# {'outputs': array([[154.92735]], dtype=float32)}
# {'outputs': array([[143.68289]], dtype=float32)}
# {'outputs': array([[134.59894]], dtype=float32)}
# {'outputs': array([[245.51129]], dtype=float32)}
# {'outputs': array([[146.95285]], dtype=float32)}
# {'outputs': array([[160.63205]], dtype=float32)}
# {'outputs': array([[136.20116]], dtype=float32)}
# {'outputs': array([[144.50677]], dtype=float32)}
# {'outputs': array([[139.38283]], dtype=float32)}
# {'outputs': array([[198.55338]], dtype=float32)}
# {'outputs': array([[135.54301]], dtype=float32)}
# {'outputs': array([[243.42256]], dtype=float32)}
# {'outputs': array([[117.22673]], dtype=float32)}
# {'outputs': array([[147.55417]], dtype=float32)}
# {'outputs': array([[147.01468]], dtype=float32)}
# {'outputs': array([[147.73653]], dtype=float32)}
# {'outputs': array([[138.86838]], dtype=float32)}
# {'outputs': array([[128.22351]], dtype=float32)}
# {'outputs': array([[159.28206]], dtype=float32)}
# {'outputs': array([[139.53069]], dtype=float32)}
# {'outputs': array([[156.10487]], dtype=float32)}
# {'outputs': array([[143.26595]], dtype=float32)}
# {'outputs': array([[132.6902]], dtype=float32)}
# {'outputs': array([[242.43092]], dtype=float32)}
# {'outputs': array([[150.94777]], dtype=float32)}
# {'outputs': array([[138.55151]], dtype=float32)}
# {'outputs': array([[247.12482]], dtype=float32)}
# {'outputs': array([[145.42583]], dtype=float32)}
# {'outputs': array([[159.38467]], dtype=float32)}
# {'outputs': array([[240.92143]], dtype=float32)}
# {'outputs': array([[167.1164]], dtype=float32)}
# {'outputs': array([[146.96594]], dtype=float32)}
# {'outputs': array([[133.1962]], dtype=float32)}
# {'outputs': array([[136.51105]], dtype=float32)}
# {'outputs': array([[236.82103]], dtype=float32)}
# {'outputs': array([[206.22466]], dtype=float32)}
# {'outputs': array([[124.946304]], dtype=float32)}
# {'outputs': array([[188.3547]], dtype=float32)}
# {'outputs': array([[135.51794]], dtype=float32)}
# {'outputs': array([[140.93951]], dtype=float32)}
# {'outputs': array([[143.9479]], dtype=float32)}
# {'outputs': array([[127.80202]], dtype=float32)}
# {'outputs': array([[157.55124]], dtype=float32)}
# {'outputs': array([[241.95418]], dtype=float32)}
# {'outputs': array([[125.86097]], dtype=float32)}
# {'outputs': array([[230.37689]], dtype=float32)}
# {'outputs': array([[135.88072]], dtype=float32)}
# {'outputs': array([[142.38878]], dtype=float32)}
# {'outputs': array([[147.08202]], dtype=float32)}
# {'outputs': array([[146.99329]], dtype=float32)}
# {'outputs': array([[134.87675]], dtype=float32)}
# {'outputs': array([[145.6268]], dtype=float32)}
# {'outputs': array([[248.18077]], dtype=float32)}
# {'outputs': array([[128.82799]], dtype=float32)}
# {'outputs': array([[122.30217]], dtype=float32)}
# {'outputs': array([[135.0438]], dtype=float32)}
# {'outputs': array([[257.65842]], dtype=float32)}
# {'outputs': array([[134.10489]], dtype=float32)}
# {'outputs': array([[148.561]], dtype=float32)}
# {'outputs': array([[228.21677]], dtype=float32)}
# {'outputs': array([[138.44933]], dtype=float32)}
# {'outputs': array([[132.78246]], dtype=float32)}
# {'outputs': array([[167.74496]], dtype=float32)}
# {'outputs': array([[196.89917]], dtype=float32)}
# {'outputs': array([[117.62478]], dtype=float32)}
# {'outputs': array([[164.27309]], dtype=float32)}
# {'outputs': array([[144.08557]], dtype=float32)}
# {'outputs': array([[242.77524]], dtype=float32)}
# {'outputs': array([[136.69638]], dtype=float32)}
# {'outputs': array([[139.63075]], dtype=float32)}
# {'outputs': array([[151.23407]], dtype=float32)}
# {'outputs': array([[144.67421]], dtype=float32)}
# {'outputs': array([[242.58722]], dtype=float32)}
# {'outputs': array([[163.4574]], dtype=float32)}
# {'outputs': array([[149.13364]], dtype=float32)}
# {'outputs': array([[140.20772]], dtype=float32)}
# {'outputs': array([[147.31497]], dtype=float32)}
# {'outputs': array([[127.43552]], dtype=float32)}
# {'outputs': array([[150.742]], dtype=float32)}
# {'outputs': array([[142.76413]], dtype=float32)}
# {'outputs': array([[143.90942]], dtype=float32)}
# {'outputs': array([[130.16528]], dtype=float32)}
# {'outputs': array([[147.26863]], dtype=float32)}
# {'outputs': array([[135.53348]], dtype=float32)}
# {'outputs': array([[241.40085]], dtype=float32)}
# {'outputs': array([[127.87253]], dtype=float32)}
# {'outputs': array([[142.35835]], dtype=float32)}
# {'outputs': array([[145.09811]], dtype=float32)}
# {'outputs': array([[164.6737]], dtype=float32)}
# {'outputs': array([[133.74765]], dtype=float32)}
# {'outputs': array([[144.25668]], dtype=float32)}
# {'outputs': array([[146.72699]], dtype=float32)}
# {'outputs': array([[240.3377]], dtype=float32)}
# {'outputs': array([[193.6686]], dtype=float32)}
# {'outputs': array([[133.9035]], dtype=float32)}
# {'outputs': array([[157.21448]], dtype=float32)}
# {'outputs': array([[149.39902]], dtype=float32)}
# {'outputs': array([[138.30502]], dtype=float32)}
# {'outputs': array([[195.45642]], dtype=float32)}
# {'outputs': array([[149.28006]], dtype=float32)}
# {'outputs': array([[152.98978]], dtype=float32)}
# {'outputs': array([[241.68129]], dtype=float32)}
# {'outputs': array([[135.57928]], dtype=float32)}
# {'outputs': array([[134.30103]], dtype=float32)}
# {'outputs': array([[159.84665]], dtype=float32)}
# {'outputs': array([[159.23463]], dtype=float32)}
# {'outputs': array([[146.90184]], dtype=float32)}
# {'outputs': array([[244.18748]], dtype=float32)}
# {'outputs': array([[241.70511]], dtype=float32)}
# {'outputs': array([[120.37276]], dtype=float32)}
# {'outputs': array([[135.57037]], dtype=float32)}
# {'outputs': array([[241.80115]], dtype=float32)}
# {'outputs': array([[131.13184]], dtype=float32)}
# {'outputs': array([[136.39604]], dtype=float32)}
# {'outputs': array([[231.257]], dtype=float32)}
# {'outputs': array([[158.66241]], dtype=float32)}
# {'outputs': array([[242.85155]], dtype=float32)}
# {'outputs': array([[132.8696]], dtype=float32)}
# {'outputs': array([[166.9025]], dtype=float32)}
# {'outputs': array([[137.34183]], dtype=float32)}
# {'outputs': array([[138.55846]], dtype=float32)}
# {'outputs': array([[140.75934]], dtype=float32)}
# {'outputs': array([[145.47495]], dtype=float32)}
# {'outputs': array([[153.44615]], dtype=float32)}
# {'outputs': array([[193.9878]], dtype=float32)}
# {'outputs': array([[237.2532]], dtype=float32)}
# {'outputs': array([[244.05925]], dtype=float32)}
# {'outputs': array([[152.67929]], dtype=float32)}
# {'outputs': array([[241.15593]], dtype=float32)}
# {'outputs': array([[135.18555]], dtype=float32)}
# {'outputs': array([[163.63913]], dtype=float32)}
# {'outputs': array([[152.57422]], dtype=float32)}
# {'outputs': array([[131.69164]], dtype=float32)}
# {'outputs': array([[139.3266]], dtype=float32)}
# {'outputs': array([[238.22647]], dtype=float32)}
# {'outputs': array([[241.94115]], dtype=float32)}
# {'outputs': array([[235.09955]], dtype=float32)}
# {'outputs': array([[141.75587]], dtype=float32)}
# {'outputs': array([[154.12086]], dtype=float32)}
# {'outputs': array([[242.95969]], dtype=float32)}
# {'outputs': array([[242.9906]], dtype=float32)}
# {'outputs': array([[238.97157]], dtype=float32)}
# {'outputs': array([[153.5835]], dtype=float32)}
# {'outputs': array([[143.95395]], dtype=float32)}
# {'outputs': array([[143.96289]], dtype=float32)}
# {'outputs': array([[246.08562]], dtype=float32)}
# {'outputs': array([[136.28285]], dtype=float32)}
# {'outputs': array([[138.46106]], dtype=float32)}
# {'outputs': array([[156.8686]], dtype=float32)}
# {'outputs': array([[135.37111]], dtype=float32)}
# {'outputs': array([[138.51407]], dtype=float32)}
# {'outputs': array([[142.85101]], dtype=float32)}
# {'outputs': array([[168.10345]], dtype=float32)}
# {'outputs': array([[152.69798]], dtype=float32)}
# {'outputs': array([[145.8877]], dtype=float32)}
# {'outputs': array([[120.67871]], dtype=float32)}
# {'outputs': array([[132.98308]], dtype=float32)}
# {'outputs': array([[146.88626]], dtype=float32)}
# {'outputs': array([[134.7908]], dtype=float32)}
# {'outputs': array([[143.0747]], dtype=float32)}
# {'outputs': array([[227.46013]], dtype=float32)}
# {'outputs': array([[145.1506]], dtype=float32)}
# {'outputs': array([[136.77701]], dtype=float32)}
# {'outputs': array([[152.319]], dtype=float32)}
# {'outputs': array([[130.10657]], dtype=float32)}
# {'outputs': array([[135.36755]], dtype=float32)}
# {'outputs': array([[141.99173]], dtype=float32)}
# {'outputs': array([[142.5047]], dtype=float32)}
# {'outputs': array([[151.83362]], dtype=float32)}
# {'outputs': array([[241.61208]], dtype=float32)}
# {'outputs': array([[154.0892]], dtype=float32)}
# {'outputs': array([[206.81778]], dtype=float32)}
# {'outputs': array([[240.46652]], dtype=float32)}
# {'outputs': array([[240.39137]], dtype=float32)}
# {'outputs': array([[220.06094]], dtype=float32)}
# {'outputs': array([[242.2883]], dtype=float32)}
# {'outputs': array([[144.64719]], dtype=float32)}
# {'outputs': array([[246.90723]], dtype=float32)}
# {'outputs': array([[210.49586]], dtype=float32)}
# {'outputs': array([[154.7309]], dtype=float32)}
# {'outputs': array([[143.16591]], dtype=float32)}
# {'outputs': array([[132.46648]], dtype=float32)}
# {'outputs': array([[147.92603]], dtype=float32)}
# {'outputs': array([[150.60175]], dtype=float32)}
# {'outputs': array([[242.26784]], dtype=float32)}
# {'outputs': array([[150.96118]], dtype=float32)}
# {'outputs': array([[241.82518]], dtype=float32)}
# {'outputs': array([[244.186]], dtype=float32)}
# {'outputs': array([[130.05511]], dtype=float32)}
# {'outputs': array([[172.64828]], dtype=float32)}
# {'outputs': array([[134.15845]], dtype=float32)}
# {'outputs': array([[245.74391]], dtype=float32)}
# {'outputs': array([[140.69543]], dtype=float32)}
# {'outputs': array([[145.52228]], dtype=float32)}
# {'outputs': array([[223.9332]], dtype=float32)}
# {'outputs': array([[135.51007]], dtype=float32)}
# {'outputs': array([[141.03745]], dtype=float32)}
# {'outputs': array([[125.22351]], dtype=float32)}
# {'outputs': array([[146.21817]], dtype=float32)}
# {'outputs': array([[123.52222]], dtype=float32)}
# {'outputs': array([[197.55392]], dtype=float32)}
# {'outputs': array([[143.56985]], dtype=float32)}
# {'outputs': array([[156.04121]], dtype=float32)}
# {'outputs': array([[168.46696]], dtype=float32)}
# {'outputs': array([[144.23703]], dtype=float32)}
# {'outputs': array([[138.50266]], dtype=float32)}
# {'outputs': array([[237.05884]], dtype=float32)}
# {'outputs': array([[156.5809]], dtype=float32)}
# {'outputs': array([[244.55522]], dtype=float32)}
# {'outputs': array([[133.96844]], dtype=float32)}
# {'outputs': array([[243.44054]], dtype=float32)}
# {'outputs': array([[156.0695]], dtype=float32)}
# {'outputs': array([[158.28244]], dtype=float32)}
# {'outputs': array([[137.43234]], dtype=float32)}
# {'outputs': array([[140.55771]], dtype=float32)}
# {'outputs': array([[243.65697]], dtype=float32)}
# {'outputs': array([[155.45328]], dtype=float32)}
# {'outputs': array([[134.26456]], dtype=float32)}
# {'outputs': array([[224.76974]], dtype=float32)}
# {'outputs': array([[125.68304]], dtype=float32)}
# {'outputs': array([[130.41565]], dtype=float32)}
# {'outputs': array([[242.42365]], dtype=float32)}
# {'outputs': array([[166.3489]], dtype=float32)}
# {'outputs': array([[149.65646]], dtype=float32)}
# {'outputs': array([[134.3462]], dtype=float32)}
# {'outputs': array([[239.97723]], dtype=float32)}
# {'outputs': array([[153.13109]], dtype=float32)}
# {'outputs': array([[143.08582]], dtype=float32)}
# {'outputs': array([[242.80281]], dtype=float32)}
# {'outputs': array([[131.75304]], dtype=float32)}
# {'outputs': array([[147.42471]], dtype=float32)}
# {'outputs': array([[159.2251]], dtype=float32)}
# {'outputs': array([[156.48048]], dtype=float32)}
# {'outputs': array([[138.60312]], dtype=float32)}
# {'outputs': array([[244.23315]], dtype=float32)}
# {'outputs': array([[146.61774]], dtype=float32)}
# {'outputs': array([[130.04205]], dtype=float32)}
# {'outputs': array([[159.8091]], dtype=float32)}
# {'outputs': array([[146.36502]], dtype=float32)}
# {'outputs': array([[142.24747]], dtype=float32)}
# {'outputs': array([[134.99109]], dtype=float32)}
# {'outputs': array([[246.03523]], dtype=float32)}
# {'outputs': array([[148.05856]], dtype=float32)}
# {'outputs': array([[126.4299]], dtype=float32)}
# {'outputs': array([[144.40451]], dtype=float32)}
# {'outputs': array([[244.64008]], dtype=float32)}
# {'outputs': array([[147.254]], dtype=float32)}
# {'outputs': array([[167.7269]], dtype=float32)}
# {'outputs': array([[132.47968]], dtype=float32)}
# {'outputs': array([[143.81693]], dtype=float32)}
# {'outputs': array([[141.24652]], dtype=float32)}
# {'outputs': array([[228.68344]], dtype=float32)}
# {'outputs': array([[140.36215]], dtype=float32)}
# {'outputs': array([[140.61966]], dtype=float32)}
# {'outputs': array([[145.18971]], dtype=float32)}
# {'outputs': array([[134.01303]], dtype=float32)}
# {'outputs': array([[195.36081]], dtype=float32)}
# {'outputs': array([[152.38528]], dtype=float32)}
# {'outputs': array([[119.10519]], dtype=float32)}
# {'outputs': array([[142.91893]], dtype=float32)}
# {'outputs': array([[111.96081]], dtype=float32)}
# {'outputs': array([[144.86166]], dtype=float32)}
# {'outputs': array([[133.44646]], dtype=float32)}
# {'outputs': array([[140.53894]], dtype=float32)}
# {'outputs': array([[241.06598]], dtype=float32)}
# {'outputs': array([[127.9186]], dtype=float32)}
# {'outputs': array([[151.13077]], dtype=float32)}
# {'outputs': array([[136.54321]], dtype=float32)}
# {'outputs': array([[164.82626]], dtype=float32)}
# {'outputs': array([[167.51361]], dtype=float32)}
# {'outputs': array([[138.73703]], dtype=float32)}
# {'outputs': array([[136.32663]], dtype=float32)}
# {'outputs': array([[129.72679]], dtype=float32)}
# {'outputs': array([[242.36761]], dtype=float32)}
# {'outputs': array([[150.97388]], dtype=float32)}
# {'outputs': array([[141.01263]], dtype=float32)}
# {'outputs': array([[167.97034]], dtype=float32)}
# {'outputs': array([[219.11961]], dtype=float32)}
# {'outputs': array([[133.97726]], dtype=float32)}
# {'outputs': array([[129.11095]], dtype=float32)}
# {'outputs': array([[237.39581]], dtype=float32)}
# {'outputs': array([[243.02087]], dtype=float32)}
# {'outputs': array([[215.23306]], dtype=float32)}
# {'outputs': array([[205.21904]], dtype=float32)}
# {'outputs': array([[136.32742]], dtype=float32)}
# {'outputs': array([[239.805]], dtype=float32)}
# {'outputs': array([[136.07791]], dtype=float32)}
# {'outputs': array([[124.30495]], dtype=float32)}
# {'outputs': array([[123.0186]], dtype=float32)}
# {'outputs': array([[154.80493]], dtype=float32)}
# {'outputs': array([[127.412704]], dtype=float32)}

# %%
path ="/tmp/models/uniform_average_ensemble_baseline/1577542872/"
#Model = tf.saved_model.load(path, )
with tf.Session(graph=tf.Graph()) as sess:
    Model = tf.saved_model.load(sess, ["serve"], export_dir= path)
    model_vars = tf.trainable_variables()
    slim.model_analyzer.analyze_vars(model_vars, print_info=True)
# Out:
# ---------
# Variables: name (type shape) [size]
# ---------
# adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/kernel:0 (float32_ref 13x64) [832, bytes: 3328]
# adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/kernel:0 (float32_ref 64x1) [64, bytes: 256]
# adanet/iteration_0/subnetwork_t0_1_layer_dnn/dense_1/bias:0 (float32_ref 1) [1, bytes: 4]
# adanet/iteration_0/ensemble_t0_1_layer_dnn_grow_complexity_regularized/weighted_subnetwork_0/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_1/subnetwork_t1_2_layer_dnn/dense/kernel:0 (float32_ref 13x64) [832, bytes: 3328]
# adanet/iteration_1/subnetwork_t1_2_layer_dnn/dense/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_1/subnetwork_t1_2_layer_dnn/dense_1/kernel:0 (float32_ref 64x64) [4096, bytes: 16384]
# adanet/iteration_1/subnetwork_t1_2_layer_dnn/dense_1/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_1/subnetwork_t1_2_layer_dnn/dense_2/kernel:0 (float32_ref 64x1) [64, bytes: 256]
# adanet/iteration_1/subnetwork_t1_2_layer_dnn/dense_2/bias:0 (float32_ref 1) [1, bytes: 4]
# adanet/iteration_1/ensemble_t1_2_layer_dnn_grow_complexity_regularized/weighted_subnetwork_0/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_1/ensemble_t1_2_layer_dnn_grow_complexity_regularized/weighted_subnetwork_1/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_2/subnetwork_t2_2_layer_dnn/dense/kernel:0 (float32_ref 13x64) [832, bytes: 3328]
# adanet/iteration_2/subnetwork_t2_2_layer_dnn/dense/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_2/subnetwork_t2_2_layer_dnn/dense_1/kernel:0 (float32_ref 64x64) [4096, bytes: 16384]
# adanet/iteration_2/subnetwork_t2_2_layer_dnn/dense_1/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_2/subnetwork_t2_2_layer_dnn/dense_2/kernel:0 (float32_ref 64x1) [64, bytes: 256]
# adanet/iteration_2/subnetwork_t2_2_layer_dnn/dense_2/bias:0 (float32_ref 1) [1, bytes: 4]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense/kernel:0 (float32_ref 13x64) [832, bytes: 3328]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense_1/kernel:0 (float32_ref 64x64) [4096, bytes: 16384]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense_1/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense_2/kernel:0 (float32_ref 64x64) [4096, bytes: 16384]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense_2/bias:0 (float32_ref 64) [64, bytes: 256]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense_3/kernel:0 (float32_ref 64x1) [64, bytes: 256]
# adanet/iteration_2/subnetwork_t2_3_layer_dnn/dense_3/bias:0 (float32_ref 1) [1, bytes: 4]
# adanet/iteration_2/ensemble_t2_2_layer_dnn_grow_complexity_regularized/weighted_subnetwork_0/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_2/ensemble_t2_2_layer_dnn_grow_complexity_regularized/weighted_subnetwork_1/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_2/ensemble_t2_2_layer_dnn_grow_complexity_regularized/weighted_subnetwork_2/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_2/ensemble_t2_3_layer_dnn_grow_complexity_regularized/weighted_subnetwork_0/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_2/ensemble_t2_3_layer_dnn_grow_complexity_regularized/weighted_subnetwork_1/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# adanet/iteration_2/ensemble_t2_3_layer_dnn_grow_complexity_regularized/weighted_subnetwork_2/logits/mixture_weight:0 (float32_ref ) [1, bytes: 4]
# Total size of variables: 20493
# Total bytes of variables: 81972

# %%
def save_model(adanet_estimator, model_dir, input_dimension):
    def serving_input_fn():
        inputs = {
            "x": tf.placeholder(dtype=tf.float32,
                                shape=[None, input_dimension],
                                name="x")
        }
        return tf.estimator.export.ServingInputReceiver(inputs, inputs)
    return adanet_estimator.estimator.export_saved_model(model_dir, serving_input_fn)

def print_model_architechture(model_dir):
    with tf.Session(graph=tf.Graph()) as sess:
        tf.saved_model.load(sess, ["serve"], model_dir)
        model_vars = tf.trainable_variables()
        slim.model_analyzer.analyze_vars(model_vars, print_info=True)
